# %%
import pandas as pd
import glob
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/home/giakhang/Desktop/debug_lerp.csv")

# %%
df_frame_280 = df[df["frame"] == 69]

# %%
df_frame_280
# Out:
#      frame  delta_t_(ms)  joint_1  joint_2  joint_3  joint_4  joint_5  joint_6
# 855     69          58.1      3.0   36.363   79.135    5.340  -90.875    1.512
# 856     69          57.5      3.0   35.919   78.531   13.270  -90.892    1.845
# 857     69          58.6      3.0   35.697   78.228   17.235  -90.900    2.012
# 858     69          59.0      3.0   35.586   78.077   19.217  -90.904    2.095
# 859     69          58.8      3.0   35.531   78.002   20.208  -90.907    2.137
# 860     69          58.2      3.0   35.503   77.964   20.704  -90.908    2.158
# 861     69          57.4      3.0   35.489   77.945   20.952  -90.908    2.168
# 862     69          53.9      3.0   35.482   77.936   21.076  -90.908    2.173
# 863     69          55.5      3.0   35.479   77.931   21.138  -90.908    2.176
# 864     69          57.2      3.0   35.477   77.929   21.169  -90.909    2.177

# %%
plt.plot(df_frame_280["joint_4"])

# %%
len(df_frame_280)
# Out:
# 10

# %%
angles_df = pd.read_csv("/home/giakhang/dev/pose_sandbox/data/2024-09-28/2024-09-28-15:12/arm_angle_2024-09-28-15:12.csv")

# %%
angles_df.iloc[:, 2].plot()
angles_df.iloc[:, 2+6].plot()

# %%
angles_df.iloc[:, 3].plot()
angles_df.iloc[:, 3+6].plot()

# %%
angles_df.iloc[:, 4].plot()
angles_df.iloc[:, 4+6].plot()

# %%
angles_df.iloc[:, 5].plot()
angles_df.iloc[:, 5+6].plot()

# %%
angles_df.iloc[:, 6].plot()
angles_df.iloc[:, 6+6].plot()

# %%
angles_df.iloc[:, 7].plot()
angles_df.iloc[:, 7+6].plot()
